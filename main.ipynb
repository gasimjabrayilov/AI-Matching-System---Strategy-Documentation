# %% [markdown]
# ## Visualizations

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

import seaborn as sns
# Out:
# C:\Users\Kasim\AppData\Local\Temp\ipykernel_20056\2095043620.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
jobs = pd.read_csv('job_descriptions.csv')

# %%
jobs.head()
# Out:
#          Job_Title                                    Job_Description
# 0        ICU Nurse  Minimum 2 years experience, BLS certification ...
# 1  Pediatric Nurse  Experience with emergency response, ACLS prefe...
# 2   Surgical Nurse  Comfortable with geriatric care, excellent bed...
# 3         ER Nurse  Familiar with advanced monitoring equipment, I...
# 4  Geriatric Nurse  Ability to work night shifts, experience with ...

# %%
nurses = pd.read_csv('nurse_profiles.csv')

# %%
nurses.head()
# Out:
#             Name          Specialty  Years_Experience   Certifications  \
# 0    Kevin Green          ICU Nurse                27        BLS, ACLS
# 1    Emma Wilson  Home Health Nurse                26  BLS, PALS, ENPC
# 2  Charlie Lewis  Psychiatric Nurse                 4  BLS, ACLS, TNCC
# 3     Liam Adams           ER Nurse                19  BLS, ACLS, TNCC
# 4      Mia Adams     Oncology Nurse                15              BLS
#
#    Patient_Satisfaction_Score  Successful_Recoveries  Shift_Type  \
# 0                        3.94                    548  Rotational
# 1                        4.90                    743         Day
# 2                        4.47                    609       Night
# 3                        4.14                    609       Night
# 4                        3.35                    329       Night
#
#   Employment_Type
# 0        Contract
# 1        Contract
# 2       Part-time
# 3       Full-time
# 4       Full-time

# %%
nurses.describe()
# Out:
#        Years_Experience  Patient_Satisfaction_Score  Successful_Recoveries
# count         100.00000                  100.000000             100.000000
# mean           14.31000                    4.036200             527.610000
# std             8.76828                    0.600737             280.197293
# min             1.00000                    3.020000              65.000000
# 25%             7.00000                    3.562500             287.500000
# 50%            12.50000                    4.075000             541.000000
# 75%            23.00000                    4.522500             749.500000
# max            30.00000                    4.990000             997.000000

# %%
nurses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Name                        100 non-null    object
#  1   Specialty                   100 non-null    object
#  2   Years_Experience            100 non-null    int64
#  3   Certifications              100 non-null    object
#  4   Patient_Satisfaction_Score  100 non-null    float64
#  5   Successful_Recoveries       100 non-null    int64
#  6   Shift_Type                  100 non-null    object
#  7   Employment_Type             100 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
sns.jointplot(x='Years_Experience',y='Patient_Satisfaction_Score',data = nurses)

# %%
nurses.head()
# Out:
#             Name          Specialty  Years_Experience   Certifications  \
# 0    Kevin Green          ICU Nurse                27        BLS, ACLS
# 1    Emma Wilson  Home Health Nurse                26  BLS, PALS, ENPC
# 2  Charlie Lewis  Psychiatric Nurse                 4  BLS, ACLS, TNCC
# 3     Liam Adams           ER Nurse                19  BLS, ACLS, TNCC
# 4      Mia Adams     Oncology Nurse                15              BLS
#
#    Patient_Satisfaction_Score  Successful_Recoveries  Shift_Type  \
# 0                        3.94                    548  Rotational
# 1                        4.90                    743         Day
# 2                        4.47                    609       Night
# 3                        4.14                    609       Night
# 4                        3.35                    329       Night
#
#   Employment_Type
# 0        Contract
# 1        Contract
# 2       Part-time
# 3       Full-time
# 4       Full-time

# %%
sns.jointplot(x='Years_Experience',y='Successful_Recoveries',data = nurses)

# %%
sns.pairplot(nurses)

# %% [markdown]
# *Based on visualization I couldn't see any connection between columns, which doesn't make coroletion*

# %%
nurses.head(10)
# Out:
#             Name          Specialty  Years_Experience   Certifications  \
# 0    Kevin Green          ICU Nurse                27        BLS, ACLS
# 1    Emma Wilson  Home Health Nurse                26  BLS, PALS, ENPC
# 2  Charlie Lewis  Psychiatric Nurse                 4  BLS, ACLS, TNCC
# 3     Liam Adams           ER Nurse                19  BLS, ACLS, TNCC
# 4      Mia Adams     Oncology Nurse                15              BLS
# 5   Julia Wilson     Surgical Nurse                22        BLS, ACLS
# 6   Emma Roberts      Cardiac Nurse                15        BLS, PALS
# 7   Fiona Wilson    Geriatric Nurse                17  BLS, PALS, ENPC
# 8   Nathan Baker  Psychiatric Nurse                12  BLS, PALS, ENPC
# 9     Alice Diaz     Oncology Nurse                11  BLS, PALS, ENPC
#
#    Patient_Satisfaction_Score  Successful_Recoveries  Shift_Type  \
# 0                        3.94                    548  Rotational
# ...
